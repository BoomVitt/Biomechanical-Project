# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\boom vitt\anaconda3\lib\site-packages (0.8.9)
# Requirement already satisfied: opencv-python in c:\users\boom vitt\anaconda3\lib\site-packages (4.5.4.60)
# Requirement already satisfied: pandas in c:\users\boom vitt\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: scikit-learn in c:\users\boom vitt\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: absl-py in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (1.0.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (3.19.1)
# Requirement already satisfied: matplotlib in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (3.4.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (4.5.4.60)
# Requirement already satisfied: wheel in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (0.37.0)
# Requirement already satisfied: six in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (1.16.0)
# Requirement already satisfied: numpy in c:\users\boom vitt\anaconda3\lib\site-packages (from mediapipe) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\boom vitt\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\boom vitt\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\boom vitt\anaconda3\lib\site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\boom vitt\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\boom vitt\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\boom vitt\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\boom vitt\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\boom vitt\anaconda3\lib\site-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\boom vitt\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.3.1)

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.4913312494754791
#   y: 0.4078141450881958
#   z: -0.8251399993896484
#   visibility: 0.9997641444206238
# }
# landmark {
#   x: 0.5058824419975281
#   y: 0.34154409170150757
#   z: -0.7775043249130249
#   visibility: 0.9994463324546814
# }
# landmark {
#   x: 0.5190541744232178
#   y: 0.3428163230419159
#   z: -0.7776764631271362
#   visibility: 0.9996122121810913
# }
# landmark {
#   x: 0.5333003997802734
#   y: 0.34464237093925476
#   z: -0.7779099345207214
#   visibility: 0.9994041919708252
# }
# landmark {
#   x: 0.4674603044986725
#   y: 0.34206971526145935
#   z: -0.788918673992157
#   visibility: 0.9994382262229919
# }
# landmark {
#   x: 0.4523373544216156
#   y: 0.34399986267089844
#   z: -0.7883390784263611
#   visibility: 0.9996083974838257
# }
# landmark {
#   x: 0.43864697217941284
#   y: 0.3462400734424591
#   z: -0.7887558937072754
#   visibility: 0.999441921710968
# }
# landmark {
#   x: 0.5559679269790649
#   y: 0.3854179382324219
#   z: -0.43667587637901306
#   visibility: 0.9994949698448181
# }
# landmark {
#   x: 0.4149203896522522
#   y: 0.3902529776096344
#   z: -0.47225484251976013
#   visibility: 0.999701738357544
# }
# landmark {
#   x: 0.5157667398452759
#   y: 0.48569047451019287
#   z: -0.6931154727935791
#   visibility: 0.9997482895851135
# }
# landmark {
#   x: 0.4651464819908142
#   y: 0.48398491740226746
#   z: -0.7032467722892761
#   visibility: 0.9997760057449341
# }
# landmark {
#   x: 0.6773408651351929
#   y: 0.7370228171348572
#   z: -0.18366336822509766
#   visibility: 0.9984993934631348
# }
# landmark {
#   x: 0.31621572375297546
#   y: 0.751846969127655
#   z: -0.327105313539505
#   visibility: 0.9989649653434753
# }
# landmark {
#   x: 0.7288651466369629
#   y: 1.1923788785934448
#   z: -0.10114459693431854
#   visibility: 0.0901477187871933
# }
# landmark {
#   x: 0.2295634001493454
#   y: 1.2029759883880615
#   z: -0.24303841590881348
#   visibility: 0.3011927306652069
# }
# landmark {
#   x: 0.743738055229187
#   y: 1.5711508989334106
#   z: -0.3835412859916687
#   visibility: 0.01624465547502041
# }
# landmark {
#   x: 0.21030405163764954
#   y: 1.5759434700012207
#   z: -0.5740839242935181
#   visibility: 0.048828206956386566
# }
# landmark {
#   x: 0.770522952079773
#   y: 1.7006903886795044
#   z: -0.4591275751590729
#   visibility: 0.020403418689966202
# }
# landmark {
#   x: 0.18069344758987427
#   y: 1.7023247480392456
#   z: -0.6779257655143738
#   visibility: 0.049562007188797
# }
# landmark {
#   x: 0.7410587668418884
#   y: 1.7151389122009277
#   z: -0.5383234024047852
#   visibility: 0.03679918497800827
# }
# landmark {
#   x: 0.21752719581127167
#   y: 1.7216655015945435
#   z: -0.7518895268440247
#   visibility: 0.08188704401254654
# }
# landmark {
#   x: 0.7252353429794312
#   y: 1.6607645750045776
#   z: -0.43377605080604553
#   visibility: 0.03666115179657936
# }
# landmark {
#   x: 0.23404769599437714
#   y: 1.6674104928970337
#   z: -0.6187467575073242
#   visibility: 0.07921535521745682
# }
# landmark {
#   x: 0.6212512254714966
#   y: 1.6060725450515747
#   z: -0.02267601154744625
#   visibility: 0.0006367902387864888
# }
# landmark {
#   x: 0.37830501794815063
#   y: 1.6101744174957275
#   z: 0.02652190998196602
#   visibility: 0.0006220992072485387
# }
# landmark {
#   x: 0.6159973740577698
#   y: 2.319608211517334
#   z: -0.09281589090824127
#   visibility: 0.0006064268527552485
# }
# landmark {
#   x: 0.3825916349887848
#   y: 2.3209445476531982
#   z: -0.05033279210329056
#   visibility: 0.000205138698220253
# }
# landmark {
#   x: 0.6255342364311218
#   y: 2.98107647895813
#   z: 0.33841150999069214
#   visibility: 0.00010833296255441383
# }
# landmark {
#   x: 0.4009816646575928
#   y: 2.983081817626953
#   z: 0.1963430941104889
#   visibility: 1.730980511638336e-05
# }
# landmark {
#   x: 0.6326731443405151
#   y: 3.085458278656006
#   z: 0.35407036542892456
#   visibility: 0.00010488898260518909
# }
# landmark {
#   x: 0.40193313360214233
#   y: 3.094517946243286
#   z: 0.20202021300792694
#   visibility: 4.760790034197271e-05
# }
# landmark {
#   x: 0.5866841077804565
#   y: 3.1890509128570557
#   z: -0.15070345997810364
#   visibility: 0.000115079281385988
# }
# landmark {
#   x: 0.43634486198425293
#   y: 3.1678900718688965
#   z: -0.33744239807128906
#   visibility: 7.986495620571077e-05
# }

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # Capture landmarks & Export to CSV

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords5.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Collect_posture"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords5.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 3.Train Custom Model
# 3.1 Read in collected data and process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords5.csv')

# %%
df.head()
# Out:
#             class        x1        y1        z1        v1        x2        y2  \
# 0  Normal_posture  0.427223  0.580501 -0.700107  0.999998  0.456238  0.503952
# 1  Normal_posture  0.428082  0.580208 -0.684176  0.999996  0.456544  0.503276
# 2  Normal_posture  0.430774  0.554068 -0.579837  0.999989  0.457836  0.477565
# 3  Normal_posture  0.434559  0.521602 -0.516760  0.999986  0.460368  0.444260
# 4  Normal_posture  0.435467  0.497162 -0.548315  0.999971  0.460427  0.422382
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0.690682  0.999990  0.472279  ... -0.016760   0.0  0.489852  0.486989
# 1 -0.680158  0.999984  0.472392  ... -0.013858   0.0  0.493400  0.471088
# 2 -0.565432  0.999965  0.473312  ... -0.013480   0.0  0.492556  0.439322
# 3 -0.501357  0.999953  0.475085  ... -0.013366   0.0  0.489909  0.428178
# 4 -0.507776  0.999918  0.475079  ... -0.009305   0.0  0.492894  0.407834
#
#        z500  v500      x501      y501      z501  v501
# 0 -0.015116   0.0  0.495108  0.479129 -0.016075   0.0
# 1 -0.009612   0.0  0.498444  0.463807 -0.010397   0.0
# 2 -0.007228   0.0  0.497792  0.430630 -0.007626   0.0
# 3 -0.008287   0.0  0.494926  0.419561 -0.008845   0.0
# 4 -0.002283   0.0  0.497450  0.399610 -0.002594   0.0
#
# [5 rows x 2005 columns]

# %%
df.tail()
# Out:
#                class        x1        y1        z1        v1        x2  \
# 617  Collect_posture  0.456556  0.489313 -0.722141  0.999927  0.475204
# 618  Collect_posture  0.466188  0.492321 -0.756287  0.999915  0.483395
# 619  Collect_posture  0.469605  0.494122 -0.760690  0.999905  0.484916
# 620  Collect_posture  0.470921  0.493550 -0.818870  0.999901  0.485912
# 621  Collect_posture  0.468943  0.492520 -0.791261  0.999896  0.484331
#
#            y2        z2        v2        x3  ...      z499  v499      x500  \
# 617  0.417467 -0.707138  0.999833  0.488286  ... -0.007491   0.0  0.511312
# 618  0.420670 -0.738163  0.999802  0.496171  ... -0.008559   0.0  0.513516
# 619  0.423707 -0.743927  0.999784  0.497185  ... -0.009029   0.0  0.514375
# 620  0.424168 -0.793112  0.999776  0.497783  ... -0.009101   0.0  0.513760
# 621  0.423170 -0.754722  0.999768  0.496509  ... -0.009646   0.0  0.511608
#
#          y500      z500  v500      x501      y501      z501  v501
# 617  0.421233  0.008248   0.0  0.514686  0.416300  0.008637   0.0
# 618  0.435453  0.007421   0.0  0.516623  0.428885  0.008039   0.0
# 619  0.440976  0.007453   0.0  0.517642  0.434015  0.008134   0.0
# 620  0.445318  0.007158   0.0  0.517167  0.437616  0.007916   0.0
# 621  0.442707  0.006539   0.0  0.515056  0.435668  0.007185   0.0
#
# [5 rows x 2005 columns]

# %%
df[df['class']=='Normal_posture']
# Out:
#               class        x1        y1        z1        v1        x2  \
# 0    Normal_posture  0.427223  0.580501 -0.700107  0.999998  0.456238
# 1    Normal_posture  0.428082  0.580208 -0.684176  0.999996  0.456544
# 2    Normal_posture  0.430774  0.554068 -0.579837  0.999989  0.457836
# 3    Normal_posture  0.434559  0.521602 -0.516760  0.999986  0.460368
# 4    Normal_posture  0.435467  0.497162 -0.548315  0.999971  0.460427
# ..              ...       ...       ...       ...       ...       ...
# 209  Normal_posture  0.490391  0.532277 -0.805703  0.999858  0.515708
# 210  Normal_posture  0.486930  0.532329 -0.799615  0.999866  0.512520
# 211  Normal_posture  0.486183  0.532983 -0.747632  0.999874  0.511230
# 212  Normal_posture  0.484080  0.531549 -0.776775  0.999878  0.508710
# 213  Normal_posture  0.482258  0.527755 -0.792987  0.999880  0.506885
#
#            y2        z2        v2        x3  ...      z499  v499      x500  \
# 0    0.503952 -0.690682  0.999990  0.472279  ... -0.016760   0.0  0.489852
# 1    0.503276 -0.680158  0.999984  0.472392  ... -0.013858   0.0  0.493400
# 2    0.477565 -0.565432  0.999965  0.473312  ... -0.013480   0.0  0.492556
# 3    0.444260 -0.501357  0.999953  0.475085  ... -0.013366   0.0  0.489909
# 4    0.422382 -0.507776  0.999918  0.475079  ... -0.009305   0.0  0.492894
# ..        ...       ...       ...       ...  ...       ...   ...       ...
# 209  0.434844 -0.767571  0.999659  0.531872  ... -0.012187   0.0  0.541142
# 210  0.434911 -0.762900  0.999677  0.528688  ... -0.012592   0.0  0.537867
# 211  0.435126 -0.717312  0.999693  0.526955  ... -0.014055   0.0  0.537938
# 212  0.431301 -0.742412  0.999702  0.524370  ... -0.013305   0.0  0.536009
# 213  0.425237 -0.754135  0.999707  0.522708  ... -0.013592   0.0  0.535480
#
#          y500      z500  v500      x501      y501      z501  v501
# 0    0.486989 -0.015116   0.0  0.495108  0.479129 -0.016075   0.0
# 1    0.471088 -0.009612   0.0  0.498444  0.463807 -0.010397   0.0
# 2    0.439322 -0.007228   0.0  0.497792  0.430630 -0.007626   0.0
# 3    0.428178 -0.008287   0.0  0.494926  0.419561 -0.008845   0.0
# 4    0.407834 -0.002283   0.0  0.497450  0.399610 -0.002594   0.0
# ..        ...       ...   ...       ...       ...       ...   ...
# 209  0.424171  0.003108   0.0  0.545945  0.417399  0.003113   0.0
# 210  0.420955  0.002597   0.0  0.542822  0.413802  0.002598   0.0
# 211  0.419841  0.001038   0.0  0.542805  0.412912  0.001030   0.0
# 212  0.418856  0.001710   0.0  0.540931  0.411216  0.001777   0.0
# 213  0.417918  0.001600   0.0  0.540355  0.410432  0.001663   0.0
#
# [214 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 228      False_posture
# 486    Collect_posture
# 513    Collect_posture
# 319      False_posture
# 353      False_posture
#             ...
# 389      False_posture
# 104     Normal_posture
# 93      Normal_posture
# 488    Collect_posture
# 553    Collect_posture
# Name: class, Length: 187, dtype: object

# %% [markdown]
# # 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# C:\Users\Boom Vitt\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['False_posture', 'False_posture', 'Collect_posture',
#        'Collect_posture', 'False_posture', 'Collect_posture',
#        'Collect_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'Collect_posture', 'Collect_posture',
#        'False_posture', 'Normal_posture', 'False_posture',
#        'False_posture', 'Normal_posture', 'False_posture',
#        'Collect_posture', 'Collect_posture', 'Normal_posture',
#        'False_posture', 'Collect_posture', 'Collect_posture',
#        'Collect_posture', 'Collect_posture', 'Collect_posture',
#        'Collect_posture', 'Normal_posture', 'False_posture',
#        'Normal_posture', 'False_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'Collect_posture', 'Normal_posture',
#        'Normal_posture', 'Normal_posture', 'False_posture',
#        'Collect_posture', 'Collect_posture', 'False_posture',
#        'Normal_posture', 'Collect_posture', 'False_posture',
#        'False_posture', 'Normal_posture', 'Normal_posture',
#        'False_posture', 'Collect_posture', 'Normal_posture',
#        'False_posture', 'False_posture', 'Normal_posture',
#        'Collect_posture', 'False_posture', 'False_posture',
#        'Collect_posture', 'Collect_posture', 'Collect_posture',
#        'Normal_posture', 'Collect_posture', 'Collect_posture',
#        'Collect_posture', 'Collect_posture', 'Normal_posture',
#        'False_posture', 'Collect_posture', 'Collect_posture',
#        'False_posture', 'Normal_posture', 'False_posture',
#        'False_posture', 'Normal_posture', 'Normal_posture',
#        'Collect_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'Normal_posture', 'False_posture',
#        'False_posture', 'False_posture', 'Collect_posture',
#        'Collect_posture', 'Collect_posture', 'Normal_posture',
#        'False_posture', 'False_posture', 'False_posture',
#        'Collect_posture', 'Collect_posture', 'False_posture'],
#       dtype='<U15')

# %% [markdown]
# # 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 0.9946524064171123
# rf 1.0
# gb 1.0

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['False_posture', 'Collect_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'Collect_posture', 'Normal_posture',
#        'Normal_posture', 'False_posture', 'Collect_posture',
#        'False_posture', 'Collect_posture', 'Normal_posture',
#        'Normal_posture', 'Collect_posture', 'False_posture',
#        'Collect_posture', 'Normal_posture', 'Normal_posture',
#        'Collect_posture', 'Collect_posture', 'Normal_posture',
#        'Collect_posture', 'Normal_posture', 'False_posture',
#        'False_posture', 'Collect_posture', 'Collect_posture',
#        'Collect_posture', 'Collect_posture', 'False_posture',
#        'Collect_posture', 'False_posture', 'Normal_posture',
#        'Normal_posture', 'Normal_posture', 'False_posture',
#        'False_posture', 'False_posture', 'Normal_posture',
#        'False_posture', 'False_posture', 'Normal_posture',
#        'Normal_posture', 'False_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'False_posture',
#        'Collect_posture', 'False_posture', 'Collect_posture',
#        'Normal_posture', 'Collect_posture', 'Normal_posture',
#        'False_posture', 'False_posture', 'Normal_posture',
#        'False_posture', 'Normal_posture', 'Normal_posture',
#        'Collect_posture', 'Collect_posture', 'Normal_posture',
#        'Collect_posture', 'Normal_posture', 'False_posture',
#        'Normal_posture', 'Normal_posture', 'Normal_posture',
#        'Collect_posture', 'Collect_posture', 'False_posture',
#        'False_posture', 'Normal_posture', 'Collect_posture',
#        'Normal_posture', 'False_posture', 'Normal_posture',
#        'Collect_posture', 'False_posture', 'False_posture',
#        'False_posture', 'Collect_posture', 'False_posture',
#        'Collect_posture', 'Normal_posture', 'False_posture',
#        'False_posture', 'Collect_posture', 'False_posture',
#        'Collect_posture', 'Normal_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'Collect_posture',
#        'Normal_posture', 'Normal_posture', 'Collect_posture',
#        'Collect_posture', 'False_posture', 'Normal_posture',
#        'Collect_posture', 'Normal_posture', 'False_posture',
#        'Normal_posture', 'Normal_posture', 'Normal_posture',
#        'Normal_posture', 'Collect_posture', 'False_posture',
#        'Normal_posture', 'Normal_posture', 'Collect_posture',
#        'Normal_posture', 'Normal_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'Normal_posture',
#        'Normal_posture', 'Normal_posture', 'Normal_posture',
#        'Normal_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'False_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'Normal_posture',
#        'Normal_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'Collect_posture', 'Collect_posture',
#        'Collect_posture', 'Collect_posture', 'False_posture',
#        'False_posture', 'Collect_posture', 'False_posture',
#        'Normal_posture', 'False_posture', 'Collect_posture',
#        'False_posture', 'Normal_posture', 'Collect_posture',
#        'Collect_posture', 'False_posture', 'False_posture',
#        'Normal_posture', 'Collect_posture', 'Normal_posture',
#        'False_posture', 'Collect_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'Collect_posture',
#        'False_posture', 'Normal_posture', 'Normal_posture',
#        'Collect_posture', 'Collect_posture', 'Collect_posture',
#        'False_posture', 'False_posture', 'Normal_posture',
#        'False_posture', 'Collect_posture', 'False_posture',
#        'Collect_posture', 'False_posture', 'Normal_posture',
#        'Normal_posture', 'Collect_posture', 'Collect_posture'],
#       dtype=object)

# %%
y_test
# Out:
# 228      False_posture
# 486    Collect_posture
# 513    Collect_posture
# 319      False_posture
# 353      False_posture
#             ...
# 389      False_posture
# 104     Normal_posture
# 93      Normal_posture
# 488    Collect_posture
# 553    Collect_posture
# Name: class, Length: 187, dtype: object

# %%
with open('posture_collect.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Posture Collect', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# Normal_posture [0.27 0.27 0.46]
# Normal_posture [0.23 0.32 0.45]
# Normal_posture [0.28 0.27 0.45]
# Normal_posture [0.28 0.27 0.45]
# Normal_posture [0.27 0.29 0.44]
# Normal_posture [0.3  0.27 0.43]
# Normal_posture [0.36 0.24 0.4 ]
# Normal_posture [0.36 0.21 0.43]
# Collect_posture [0.41 0.18 0.41]
# Normal_posture [0.39 0.21 0.4 ]
# Collect_posture [0.38 0.25 0.37]
# Collect_posture [0.38 0.24 0.38]
# Normal_posture [0.33 0.25 0.42]
# Normal_posture [0.32 0.28 0.4 ]
# Normal_posture [0.38 0.17 0.45]
# Normal_posture [0.33 0.28 0.39]
# Normal_posture [0.33 0.26 0.41]
# Normal_posture [0.33 0.28 0.39]
# Normal_posture [0.21 0.28 0.51]
# Normal_posture [0.2  0.22 0.58]
# Normal_posture [0.18 0.22 0.6 ]
# Normal_posture [0.21 0.21 0.58]
# Normal_posture [0.25 0.25 0.5 ]
# Normal_posture [0.28 0.24 0.48]
# Normal_posture [0.26 0.24 0.5 ]
# Normal_posture [0.28 0.23 0.49]
# Normal_posture [0.28 0.21 0.51]
# Normal_posture [0.27 0.2  0.53]
# Normal_posture [0.22 0.2  0.58]
# Normal_posture [0.28 0.18 0.54]
# Normal_posture [0.35 0.19 0.46]
# Normal_posture [0.3  0.18 0.52]
# Normal_posture [0.35 0.18 0.47]
# Normal_posture [0.36 0.18 0.46]
# Normal_posture [0.38 0.18 0.44]
# Normal_posture [0.35 0.18 0.47]
# Normal_posture [0.35 0.18 0.47]
# Normal_posture [0.3  0.17 0.53]
# Normal_posture [0.25 0.2  0.55]
# Normal_posture [0.32 0.18 0.5 ]
# Normal_posture [0.27 0.15 0.58]
# Normal_posture [0.29 0.14 0.57]
# Normal_posture [0.33 0.17 0.5 ]
# Normal_posture [0.37 0.17 0.46]
# Collect_posture [0.41 0.18 0.41]
# Normal_posture [0.39 0.2  0.41]
# Normal_posture [0.37 0.21 0.42]
# Normal_posture [0.36 0.22 0.42]
# Normal_posture [0.37 0.21 0.42]
# Normal_posture [0.36 0.2  0.44]
# Normal_posture [0.38 0.2  0.42]
# Normal_posture [0.37 0.2  0.43]
# Normal_posture [0.35 0.19 0.46]
# Normal_posture [0.36 0.17 0.47]
# Normal_posture [0.34 0.18 0.48]
# Normal_posture [0.32 0.18 0.5 ]
# Normal_posture [0.35 0.16 0.49]
# Normal_posture [0.36 0.15 0.49]
# Normal_posture [0.36 0.15 0.49]
# Normal_posture [0.36 0.17 0.47]
# Normal_posture [0.34 0.17 0.49]
# Normal_posture [0.36 0.17 0.47]
# Normal_posture [0.34 0.17 0.49]
# Normal_posture [0.31 0.18 0.51]
# Normal_posture [0.35 0.17 0.48]
# Normal_posture [0.35 0.18 0.47]
# Normal_posture [0.34 0.17 0.49]
# Normal_posture [0.35 0.17 0.48]
# Normal_posture [0.38 0.18 0.44]
# Normal_posture [0.38 0.17 0.45]
# Normal_posture [0.35 0.16 0.49]
# Normal_posture [0.35 0.18 0.47]
# Normal_posture [0.39 0.18 0.43]
# Normal_posture [0.37 0.21 0.42]
# Collect_posture [0.41 0.22 0.37]
# Collect_posture [0.47 0.23 0.3 ]
# Collect_posture [0.55 0.22 0.23]
# Collect_posture [0.51 0.26 0.23]
# Collect_posture [0.56 0.24 0.2 ]
# Collect_posture [0.59 0.26 0.15]
# Collect_posture [0.6  0.24 0.16]
# Collect_posture [0.64 0.23 0.13]
# Collect_posture [0.67 0.21 0.12]
# Collect_posture [0.6  0.23 0.17]
# Collect_posture [0.61 0.24 0.15]
# Collect_posture [0.66 0.23 0.11]
# Collect_posture [0.71 0.2  0.09]
# Collect_posture [0.75 0.16 0.09]
# Collect_posture [0.74 0.15 0.11]
# Collect_posture [0.76 0.16 0.08]
# Collect_posture [0.75 0.17 0.08]
# Collect_posture [0.75 0.18 0.07]
# Collect_posture [0.71 0.22 0.07]
# Collect_posture [0.73 0.21 0.06]
# Collect_posture [0.73 0.21 0.06]
# Collect_posture [0.73 0.22 0.05]
# Collect_posture [0.71 0.22 0.07]
# Collect_posture [0.72 0.21 0.07]
# Collect_posture [0.71 0.21 0.08]
# Collect_posture [0.72 0.21 0.07]
# Collect_posture [0.7  0.21 0.09]
# Collect_posture [0.69 0.21 0.1 ]
# Collect_posture [0.71 0.19 0.1 ]
# Collect_posture [0.72 0.18 0.1 ]
# Collect_posture [0.72 0.18 0.1 ]
# Collect_posture [0.71 0.22 0.07]
# Collect_posture [0.67 0.24 0.09]
# Collect_posture [0.72 0.19 0.09]
# Collect_posture [0.7  0.21 0.09]
# Collect_posture [0.7  0.21 0.09]
# Collect_posture [0.7  0.21 0.09]
# Collect_posture [0.7 0.2 0.1]
# Collect_posture [0.7 0.2 0.1]
# Collect_posture [0.71 0.2  0.09]
# Collect_posture [0.71 0.19 0.1 ]
# Collect_posture [0.7  0.21 0.09]
# Collect_posture [0.7  0.21 0.09]
# Collect_posture [0.7  0.22 0.08]
# Collect_posture [0.7  0.22 0.08]
# Collect_posture [0.71 0.22 0.07]
# Collect_posture [0.72 0.16 0.12]
# Collect_posture [0.66 0.15 0.19]
# Collect_posture [0.66 0.15 0.19]
# Collect_posture [0.65 0.17 0.18]
# Collect_posture [0.66 0.16 0.18]
# Collect_posture [0.65 0.18 0.17]
# Collect_posture [0.73 0.19 0.08]
# Collect_posture [0.82 0.15 0.03]
# Collect_posture [0.86 0.11 0.03]
# Collect_posture [0.86 0.1  0.04]
# Collect_posture [0.8  0.16 0.04]
# Collect_posture [0.8  0.16 0.04]
# Collect_posture [0.79 0.17 0.04]
# Collect_posture [0.84 0.12 0.04]
# Collect_posture [0.83 0.13 0.04]
# Collect_posture [0.81 0.15 0.04]
# Collect_posture [0.81 0.15 0.04]
# Collect_posture [0.77 0.14 0.09]
# Collect_posture [0.75 0.13 0.12]
# Collect_posture [0.77 0.12 0.11]
# Collect_posture [0.77 0.14 0.09]
# Collect_posture [0.75 0.18 0.07]
# Collect_posture [0.76 0.17 0.07]
# Collect_posture [0.66 0.23 0.11]
# Collect_posture [0.6  0.27 0.13]
# Collect_posture [0.58 0.29 0.13]
# Collect_posture [0.55 0.34 0.11]
# Collect_posture [0.54 0.36 0.1 ]
# Collect_posture [0.5  0.39 0.11]
# Collect_posture [0.52 0.38 0.1 ]
# Collect_posture [0.62 0.28 0.1 ]
# Collect_posture [0.63 0.28 0.09]
# Collect_posture [0.55 0.35 0.1 ]
# Collect_posture [0.59 0.32 0.09]
# Collect_posture [0.6  0.31 0.09]
# Collect_posture [0.62 0.3  0.08]
# Collect_posture [0.67 0.25 0.08]
# Collect_posture [0.7  0.23 0.07]
# Collect_posture [0.67 0.24 0.09]
# Collect_posture [0.71 0.2  0.09]
# Collect_posture [0.72 0.19 0.09]
# Collect_posture [0.68 0.24 0.08]
# Collect_posture [0.71 0.22 0.07]
# Collect_posture [0.68 0.23 0.09]
# Collect_posture [0.68 0.23 0.09]
# Collect_posture [0.67 0.24 0.09]
# Collect_posture [0.73 0.19 0.08]
# Collect_posture [0.64 0.23 0.13]
# Collect_posture [0.59 0.3  0.11]
# Collect_posture [0.6 0.3 0.1]
# Collect_posture [0.61 0.31 0.08]
# Collect_posture [0.62 0.29 0.09]
# Collect_posture [0.65 0.25 0.1 ]
# Collect_posture [0.68 0.23 0.09]
# Collect_posture [0.73 0.2  0.07]
# Collect_posture [0.75 0.18 0.07]
# Collect_posture [0.81 0.14 0.05]
# Collect_posture [0.77 0.17 0.06]
# Collect_posture [0.83 0.13 0.04]
# Collect_posture [0.83 0.13 0.04]
# Collect_posture [0.82 0.13 0.05]
# Collect_posture [0.84 0.12 0.04]
# Collect_posture [0.85 0.12 0.03]
# Collect_posture [0.87 0.1  0.03]
# Collect_posture [0.86 0.11 0.03]
# Collect_posture [0.86 0.1  0.04]
# Collect_posture [0.85 0.11 0.04]
# Collect_posture [0.83 0.13 0.04]
# Collect_posture [0.83 0.14 0.03]
# Collect_posture [0.77 0.12 0.11]
# Collect_posture [0.83 0.08 0.09]
# Collect_posture [0.84 0.07 0.09]
# Collect_posture [0.86 0.06 0.08]
# Collect_posture [0.86 0.05 0.09]
# Collect_posture [0.87 0.04 0.09]
# Collect_posture [0.86 0.03 0.11]
# Collect_posture [0.86 0.03 0.11]
# Collect_posture [0.85 0.04 0.11]
# Collect_posture [0.81 0.06 0.13]
# Collect_posture [0.81 0.06 0.13]
# Collect_posture [0.8  0.06 0.14]
# Collect_posture [0.81 0.06 0.13]
# Collect_posture [0.85 0.06 0.09]
# Collect_posture [0.84 0.07 0.09]
# Collect_posture [0.86 0.06 0.08]
# Collect_posture [0.85 0.07 0.08]
# Collect_posture [0.78 0.08 0.14]
# Collect_posture [0.88 0.07 0.05]
# Collect_posture [0.87 0.08 0.05]
# Collect_posture [0.88 0.08 0.04]
# Collect_posture [0.92 0.06 0.02]
# Collect_posture [0.92 0.06 0.02]
# Collect_posture [0.9  0.08 0.02]
# Collect_posture [0.91 0.07 0.02]
# Collect_posture [0.9  0.07 0.03]
# Collect_posture [0.9  0.07 0.03]
# Collect_posture [0.88 0.08 0.04]
# Collect_posture [0.82 0.12 0.06]
# Collect_posture [0.82 0.14 0.04]
# Collect_posture [0.85 0.1  0.05]
# Collect_posture [0.85 0.1  0.05]
# Collect_posture [0.81 0.11 0.08]
# Collect_posture [0.74 0.16 0.1 ]
# Collect_posture [0.74 0.16 0.1 ]
# Collect_posture [0.71 0.19 0.1 ]
# Collect_posture [0.63 0.26 0.11]
# Collect_posture [0.62 0.25 0.13]
# Collect_posture [0.62 0.25 0.13]
# Collect_posture [0.68 0.21 0.11]
# Collect_posture [0.87 0.09 0.04]
# Collect_posture [0.92 0.06 0.02]
# Collect_posture [0.92 0.06 0.02]
# Collect_posture [0.89 0.07 0.04]
# Collect_posture [0.88 0.08 0.04]
# Collect_posture [0.89 0.08 0.03]
# Collect_posture [0.89 0.09 0.02]
# Collect_posture [0.89 0.09 0.02]
# Collect_posture [0.91 0.08 0.01]
# Collect_posture [0.91 0.08 0.01]
# Collect_posture [0.92 0.08 0.  ]
# Collect_posture [0.93 0.07 0.  ]
# Collect_posture [0.88 0.1  0.02]
# Collect_posture [0.79 0.14 0.07]
# Collect_posture [0.7  0.18 0.12]
# False_posture [0.39 0.42 0.19]
# False_posture [0.32 0.52 0.16]
# False_posture [0.2  0.64 0.16]
# False_posture [0.18 0.66 0.16]
# False_posture [0.14 0.69 0.17]
# False_posture [0.15 0.69 0.16]
# False_posture [0.18 0.66 0.16]
# False_posture [0.18 0.66 0.16]
# False_posture [0.18 0.67 0.15]
# False_posture [0.15 0.7  0.15]
# False_posture [0.17 0.66 0.17]
# False_posture [0.17 0.64 0.19]
# False_posture [0.12 0.67 0.21]
# False_posture [0.14 0.65 0.21]
# False_posture [0.14 0.65 0.21]
# False_posture [0.15 0.64 0.21]
# False_posture [0.14 0.65 0.21]
# False_posture [0.13 0.66 0.21]
# False_posture [0.13 0.66 0.21]
# False_posture [0.15 0.64 0.21]
# False_posture [0.17 0.63 0.2 ]
# False_posture [0.17 0.63 0.2 ]
# False_posture [0.17 0.63 0.2 ]
# False_posture [0.18 0.62 0.2 ]
# False_posture [0.18 0.62 0.2 ]
# False_posture [0.19 0.6  0.21]
# False_posture [0.19 0.6  0.21]
# False_posture [0.29 0.52 0.19]
# False_posture [0.27 0.52 0.21]
# Collect_posture [0.54 0.29 0.17]
# Collect_posture [0.46 0.31 0.23]
# False_posture [0.34 0.36 0.3 ]
# Collect_posture [0.72 0.18 0.1 ]
# Collect_posture [0.78 0.19 0.03]
# Collect_posture [0.85 0.11 0.04]
# Collect_posture [0.93 0.04 0.03]
# Collect_posture [0.9  0.06 0.04]
# Collect_posture [0.9  0.06 0.04]
# Collect_posture [0.95 0.03 0.02]
# Collect_posture [0.9  0.03 0.07]
# Collect_posture [0.82 0.1  0.08]
# Collect_posture [0.79 0.11 0.1 ]
# Collect_posture [0.75 0.14 0.11]
# Collect_posture [0.74 0.15 0.11]
# Collect_posture [0.73 0.1  0.17]
# Normal_posture [0.24 0.17 0.59]
# Normal_posture [0.22 0.17 0.61]
# Normal_posture [0.3  0.14 0.56]
# Normal_posture [0.29 0.15 0.56]
# Normal_posture [0.24 0.13 0.63]
# Normal_posture [0.24 0.15 0.61]
# Normal_posture [0.24 0.15 0.61]
# Normal_posture [0.22 0.14 0.64]
# Normal_posture [0.27 0.15 0.58]
# Normal_posture [0.29 0.11 0.6 ]
# Normal_posture [0.2  0.15 0.65]
# Normal_posture [0.2  0.17 0.63]
# Normal_posture [0.28 0.15 0.57]
# Normal_posture [0.24 0.17 0.59]
# Normal_posture [0.25 0.17 0.58]
# Normal_posture [0.25 0.21 0.54]
# Normal_posture [0.26 0.21 0.53]
# Normal_posture [0.25 0.22 0.53]
# Normal_posture [0.24 0.22 0.54]
# Normal_posture [0.26 0.2  0.54]
# Normal_posture [0.28 0.21 0.51]
# Normal_posture [0.28 0.19 0.53]
# Normal_posture [0.33 0.17 0.5 ]
# Normal_posture [0.36 0.18 0.46]
# Normal_posture [0.34 0.21 0.45]
# Collect_posture [0.43 0.17 0.4 ]
# Collect_posture [0.46 0.13 0.41]
# Collect_posture [0.46 0.14 0.4 ]
# Collect_posture [0.48 0.17 0.35]
# Collect_posture [0.5  0.14 0.36]
# Collect_posture [0.44 0.17 0.39]
# Collect_posture [0.46 0.16 0.38]
# Normal_posture [0.39 0.21 0.4 ]
# Normal_posture [0.28 0.3  0.42]
# Normal_posture [0.36 0.19 0.45]
# Normal_posture [0.35 0.17 0.48]
# Normal_posture [0.33 0.17 0.5 ]
# Normal_posture [0.36 0.14 0.5 ]
# Normal_posture [0.32 0.18 0.5 ]
# Normal_posture [0.36 0.14 0.5 ]
# Normal_posture [0.34 0.16 0.5 ]
# Normal_posture [0.38 0.11 0.51]
# Normal_posture [0.35 0.11 0.54]
# Normal_posture [0.31 0.11 0.58]
# Normal_posture [0.32 0.11 0.57]
# Normal_posture [0.34 0.12 0.54]
# Collect_posture [0.41 0.19 0.4 ]
# Collect_posture [0.5  0.13 0.37]
# Collect_posture [0.5  0.14 0.36]
# Collect_posture [0.43 0.19 0.38]
# Collect_posture [0.49 0.16 0.35]
# Collect_posture [0.48 0.17 0.35]
# Collect_posture [0.52 0.15 0.33]
# Collect_posture [0.52 0.15 0.33]
# Collect_posture [0.45 0.22 0.33]
# Collect_posture [0.42 0.27 0.31]
# Collect_posture [0.45 0.23 0.32]
# Collect_posture [0.49 0.19 0.32]
# Collect_posture [0.45 0.26 0.29]
# Collect_posture [0.5  0.21 0.29]
# Collect_posture [0.46 0.24 0.3 ]
# Collect_posture [0.49 0.18 0.33]
# Collect_posture [0.48 0.2  0.32]
# Collect_posture [0.44 0.27 0.29]
# Collect_posture [0.43 0.28 0.29]
# Collect_posture [0.43 0.29 0.28]
# Collect_posture [0.42 0.27 0.31]
# Collect_posture [0.41 0.27 0.32]
# Collect_posture [0.42 0.28 0.3 ]
# Collect_posture [0.46 0.23 0.31]
# Collect_posture [0.49 0.18 0.33]
# Collect_posture [0.45 0.16 0.39]
# Normal_posture [0.4  0.15 0.45]
# Normal_posture [0.37 0.14 0.49]
# Normal_posture [0.39 0.13 0.48]
# Collect_posture [0.42 0.18 0.4 ]
# Collect_posture [0.43 0.19 0.38]
# Collect_posture [0.46 0.17 0.37]
# Collect_posture [0.45 0.16 0.39]
# Collect_posture [0.47 0.17 0.36]
# Collect_posture [0.42 0.17 0.41]
# Normal_posture [0.39 0.17 0.44]
# Normal_posture [0.34 0.15 0.51]
# Normal_posture [0.33 0.18 0.49]
# Normal_posture [0.34 0.16 0.5 ]
# Normal_posture [0.33 0.23 0.44]
